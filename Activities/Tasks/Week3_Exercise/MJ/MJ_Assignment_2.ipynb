# %% [markdown]
# ## Exercise : Generate 200 data from GPT, Describe the data

# %%
# Import pandas library, aliased as `pd`
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Importing 200 datasets of student
data = pd.read_csv("3Logy-NDI-AI-ML-Crash/datasets/student_performance_200.csv")
data.head()
# Out:
#   Student_ID  Age  Study_Hours  Attendance_Percentage  Assignment_Score  \
# 0      ST001   28            2                     61                97
# 1      ST002   21            4                     68                97
# 2      ST003   28            2                     97                77
# 3      ST004   18            2                     73                64
# 4      ST005   27            1                     95                62
#
#    Final_Exam_Score
# 0                56
# 1                61
# 2                40
# 3                48
# 4                46

# %%
# Importing 200 datasets of student
data = pd.read_csv("3Logy-NDI-AI-ML-Crash/datasets/student_performance_200.csv")

# %%
data
# Out:
#     Student_ID  Age  Study_Hours  Attendance_Percentage  Assignment_Score  \
# 0        ST001   28            2                     61                97
# 1        ST002   21            4                     68                97
# 2        ST003   28            2                     97                77
# 3        ST004   18            2                     73                64
# 4        ST005   27            1                     95                62
# ..         ...  ...          ...                    ...               ...
# 195      ST196   25            8                     77                61
# 196      ST197   24            8                     65                80
# 197      ST198   24            6                     80                92
# 198      ST199   20            6                     86                94
# 199      ST200   22            7                     95                52
#
#      Final_Exam_Score
# 0                  56
# 1                  61
# ...

# %%
#Data types
data.dtypes
# Out:
# Student_ID                 str
# Age                      int64
# Study_Hours              int64
# Attendance_Percentage    int64
# Assignment_Score         int64
# Final_Exam_Score         int64
# dtype: object

# %%
data.columns
# Out:
# Index(['Student_ID', 'Age', 'Study_Hours', 'Attendance_Percentage',
#        'Assignment_Score', 'Final_Exam_Score'],
#       dtype='str')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
data_columns = data.columns
data_columns
# Out:
# Index(['Student_ID', 'Age', 'Study_Hours', 'Attendance_Percentage',
#        'Assignment_Score', 'Final_Exam_Score'],
#       dtype='str')

# %%
data.shape
# Out:
# (200, 6)

# %%
#from IPython.display import Image, display

display(Image("3Logy-NDI-AI-ML-Crash/images/Anatomy_of_student.png"))
