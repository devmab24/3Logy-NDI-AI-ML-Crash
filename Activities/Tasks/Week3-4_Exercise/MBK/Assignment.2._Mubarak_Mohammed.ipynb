# %% [markdown]
# # Exercise

# %%
# Import pandas library, aliased as `pd`
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Solution

# %%
# Import dataset
data = pd.read_csv("C:/Users/msheh/Desktop/AI_ML001/3Logy-NDI-AI-ML-Crash/datasets/retail_transactions_200.csv")

# %%
data.head(10)
# Out:
#    ID  Customer_Age  Gender Product_Category  Purchase_Amount_USD  \
# 0   1            28    Male        Furniture                  775
# 1   2            27    Male           Beauty                   57
# 2   3            26    Male         Clothing                  114
# 3   4            33  Female         Clothing                  107
# 4   5            21    Male        Groceries                   61
# 5   6            34  Female      Electronics                  247
# 6   7            43  Female           Beauty                   46
# 7   8            50    Male        Groceries                   45
# 8   9            44    Male      Electronics                  223
# 9  10            39    Male         Clothing                   62
#
#   Payment_Method  Satisfaction_1_to_5
# 0           Cash                    3
# 1           Cash                    3
# 2         Mobile                    3
# 3         Mobile                    4
# 4           Card                    3
# 5           Card                    3
# 6           Cash                    5
# 7         Mobile                    4
# 8         Mobile                    3
# 9           Card                    4

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# C:\Users\msheh\Desktop\AI_ML001

# %%
data
# Out:
#       ID  Customer_Age  Gender Product_Category  Purchase_Amount_USD  \
# 0      1            28    Male        Furniture                  775
# 1      2            27    Male           Beauty                   57
# 2      3            26    Male         Clothing                  114
# 3      4            33  Female         Clothing                  107
# 4      5            21    Male        Groceries                   61
# ..   ...           ...     ...              ...                  ...
# 195  196            44    Male      Electronics                  351
# 196  197            47    Male         Clothing                   66
# 197  198            54  Female         Clothing                   82
# 198  199            42    Male        Groceries                   44
# 199  200            46  Female      Electronics                  402
#
#     Payment_Method  Satisfaction_1_to_5
# 0             Cash                    3
# 1             Cash                    3
# 2           Mobile                    3
# 3           Mobile                    4
# 4             Card                    3
# ..             ...                  ...
# 195           Card                    5
# 196         Mobile                    4
# 197           Card                    4
# 198           Cash                    3
# 199           Cash                    4
#
# [200 rows x 7 columns]

# %%
#Data types
data.dtypes
# Out:
# ID                     int64
# Customer_Age           int64
# Gender                   str
# Product_Category         str
# Purchase_Amount_USD    int64
# Payment_Method           str
# Satisfaction_1_to_5    int64
# dtype: object

# %%
# This returns the column names as a list
# Index is a data structure used by Pandas to store labels for rows and columns. i.e here we've column index
data.columns
# Out:
# Index(['ID', 'Customer_Age', 'Gender', 'Product_Category',
#        'Purchase_Amount_USD', 'Payment_Method', 'Satisfaction_1_to_5'],
#       dtype='str')

# %%
# This returns the index
data.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
#If you're interested in understanding the dimensionality of the DataFrame, we can use the df.shape method. The code looks like this:
data.shape
print("df_houses shape:", data.shape)
# Out:
# df_houses shape: (200, 7)
