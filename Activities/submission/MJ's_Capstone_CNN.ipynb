# %% [markdown]
# ### 🚀 Capston CNN on Equipment Fault Detection System
#
# * **Live Streamlit App:** [Click here to view the Demo](https://equipment-fault-detection-system-dahwzw95kmzhlu4x45subd.streamlit.app/)
# * **GitHub Repository:** [Click here to view the Source Code](https://github.com/murjanatujaafaru-a11y/Equipment-Fault-Detection-System)
