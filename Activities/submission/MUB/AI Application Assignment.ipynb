# %% [markdown]
# **Presentation slides link** = https://canva.link/heinuhae4e64hgp

# %%
AI Application explanation link = https://root-night-a34.notion.site/AI-ML-in-Oil-Gas-Slide-Deck-364c029328f080fe989ae1155b1689f5?source=copy_link
