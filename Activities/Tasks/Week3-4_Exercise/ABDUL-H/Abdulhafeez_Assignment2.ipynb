# %% [markdown]
# # Assignment

# %%
# Import pandas library, aliased as `pd`
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("All imports successful!")
# Out:
# All imports successful!

# %%
data = pd.read_csv ("3Logy-NDI-AI-ML-Crash/assignment data/perfume_sales.csv")
data.head(10)
# Out:
#    sale_id   sale_date           brand         model  year price_usd  \
# 0        1  12/03/2024            Dior       J'adore  2021    $66193
# 1        2  13/08/2024    Calvin Klein        Escape  2022    $30244
# 2        3  20/09/2024           Gucci        Guilty  2023    $49598
# 3        4  01/01/2024       Hugo Boss     The Scent  2024    $80922
# 4        5  07/07/2024             YSL         Libre  2024    $45947
# 5        6  06/09/2024    Calvin Klein     Obsession  2024    $15152
# 6        7  06/09/2024        Burberry          Brit  2020    $66815
# 7        8  19/08/2024           Gucci        Bamboo  2023    $48650
# 8        9  12/06/2024  Giorgio Armani  Acqua di Gio  2021    $89937
# 9       10  11/01/2024       Hugo Boss     The Scent  2020    $45680
#
#    quantity_sold     store_city
# 0              2          Lagos
# 1              7          Lagos
# 2              1         Ibadan
# 3              4  Port Harcourt
# 4              6          Abuja
# ...

# %%
from IPython.display import Image, display
display(Image("3Logy-NDI-AI-ML-Crash/assignment image/perfume_sales_anatomy.png"))

# %%
data.dtypes
# Out:
# sale_id          int64
# sale_date          str
# brand              str
# model              str
# year             int64
# price_usd          str
# quantity_sold    int64
# store_city         str
# dtype: object

# %%
data.columns
# Out:
# Index(['sale_id', 'sale_date', 'brand', 'model', 'year', 'price_usd',
#        'quantity_sold', 'store_city'],
#       dtype='str')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
data_columns = data.columns
data_columns
# Out:
# Index(['sale_id', 'sale_date', 'brand', 'model', 'year', 'price_usd',
#        'quantity_sold', 'store_city'],
#       dtype='str')

# %%
data.shape
# Out:
# (200, 8)

# %%
data.shape
print("df_houses shape:", data.shape)
# Out:
# df_houses shape: (200, 8)

# %%
data.describe()
# Out:
#           sale_id         year  quantity_sold
# count  200.000000   200.000000     200.000000
# mean   100.500000  2021.880000       5.630000
# std     57.879185     1.412649       2.787823
# min      1.000000  2020.000000       1.000000
# 25%     50.750000  2021.000000       3.000000
# 50%    100.500000  2022.000000       6.000000
# 75%    150.250000  2023.000000       8.000000
# max    200.000000  2024.000000      10.000000

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sale_id        200 non-null    int64
#  1   sale_date      200 non-null    str
#  2   brand          200 non-null    str
#  3   model          200 non-null    str
#  4   year           200 non-null    int64
#  5   price_usd      200 non-null    str
#  6   quantity_sold  200 non-null    int64
#  7   store_city     200 non-null    str
# dtypes: int64(3), str(5)
# memory usage: 12.6 KB

# %%
data = pd.Series([2, 4, 6, 8,])
print(data.mean())
# Out:
# 5.0

# %%
data.sum()
# Out:
# np.int64(20)
