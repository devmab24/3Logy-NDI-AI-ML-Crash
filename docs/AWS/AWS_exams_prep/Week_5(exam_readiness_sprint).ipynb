# %% [markdown]
# # Exam readiness sprint

# %% [markdown]
# **What we would NOT spend time on.**
#
# - Building deep neural networks from scratch
# - Advanced PyTorch coding
# - Complex mathematics
# - CNN architectures
# - Transformer internals
#
# **Note**: *The AI practitioner exam is designed for foundational understanding, AWS service awareness, and practical AI concepts—not ML engineering specialization.*

# %% [markdown]
# # Tool stack we'll use:
#
#
# | Tool                    | Purpose             |
# | ----------------------- | ------------------- |
# | Jupyter notebook        | AI concepts         |
# | AWS skill builder       | Official learning   |
# | AWS free tier           | Hands-on AWS        |
# | SageMaker studio        | ML workflow         |
# | Amazon bedrock          | Generative AI       |
# | PartyRock               | Prompt Engineering  |
# | Notion/Trello           | Progress tracking   |
# | GitHub                  | Notes & labs        |
#
# ---
#
# **NOTE**: You already have AI/ML exposure from your previous training. What you need now is to learn how AWS names, packages, secures, and deploys those concepts so they can recognize them immediately in exam scenarios.
