# %% [markdown]
# ## Datasets repo:
#
# url_classification: https://raw.githubusercontent.com/blastchar/telco-customer-churn/master/WA_Fn-UseC_-Telco-Customer-Churn.csv
#
# url_clustering: https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mall_customers.csv

# %% [markdown]
# # A “BUILD SESSION”: GRADED
#
# ## Objective
#
# By the end of the class:
#
# > Every student builds and evaluates a working ML model
#
# NOTE:
# > “No lecture today. You’re building a model. Submission ends before class ends.”
#
# *No slides. No intro. Just pressure.*
#
# ---
#
# ## Phase 1: ⏱️ Duration (2 HOURS)
#
# ---
#
# ## Phase 2: Problem Drop (*clear, real-world task*)
#
# ### Option A (Classification)
#
# > “A telecom company is losing customers every month.
# You have their data.
# Build a model to predict who will churn(leave).”
#
# ### Option B (Clustering – ties to your deployment)
#
# > “A company wants to segment customers. Build a clustering model and interpret clusters.”
#
# ### Deploy your model using the Jupyter Inference UI
#
# ---
#
# ## Phase 3: Starter Code
#
# > “Not available”
#
# ---
#
# # Phase 4: Forced Engagement Loop
#
# ---
#
# ## LOOP STRUCTURE (Repeat 3 times)
#
# ### Step 1: Micro-Instruction
#
# #### Loop 1:
#
# > “Train ONE model (Logistic Regression or KMeans)”
#
# #### Loop 2:
#
# > “Evaluate your model (Accuracy / Silhouette Score)”
#
# #### Loop 3:
#
# > “Improve your model (tuning or feature scaling or new model)”
#
# ---
#
# ### Step 2: Execution
#
# Your Instructor's role today is to:
#
# * Walk around
# * Watch your screens
# * Apply pressure i.e:
#
#   * “Why did you choose that model?”
#   * “What’s your accuracy?”
#   * “Why is this wrong?”
#
# ---
#
# ### Step 3: Random Call-Out
#
# I'll randomly call anyone to:
#
# > “Share his/her screen.
# >
# > Explain his/her model.”
#
# ---
#
# # Phase 5: The Twist
#
# ### Option A:
#
# > “Convert your model into a simple prediction function”
#
# Example:
#
# ```python
# def predict(input_data):
#     input_scaled = scaler.transform([input_data])
#     return model.predict(input_scaled)
# ```
#
# ### Option B (Advance):
#
# > “Prepare this model and deploy (save it first)”
#
# ```python
# import joblib
# joblib.dump(model, "model.pkl")
# ```

# %% [markdown]
# # Phase 6: Leaderboard
# I'll rank each student based on the metrics below.
#
# | Name | Score | Model |
# | ---- | ----- | ----- |
#
# Ranking:
#
# * Best accuracy
# * Best explanation
# * Best improvement

# %% [markdown]
# # Phase 7: Closing
#
# Note:
#
# > “This is how real ML work happens.”

# %% [markdown]
# # PSYCHOLOGICAL TRIGGERS
#
# This session activates:
#
# * **Urgency** → time pressure
# * **Visibility** → screen sharing
# * **Competition** → leaderboard
# * **Ownership** → real problem
# * **Fear of embarrassment** → random calling
