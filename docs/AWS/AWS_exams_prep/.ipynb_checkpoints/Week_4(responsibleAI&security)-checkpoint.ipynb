# %% [markdown]
# # Responsible AI & security

# %% [markdown]
# **Topics**:
#
# - Bias
# - Fairness
# - Transparency
# - Explainability
# - Hallucinations
# - Prompt injection
# - Data leakage
# - Privacy
#
# Note: *The guide explicitly includes these concepts*
#
# ---
#
# **AWS services**: We'll introduce:-
#
# - IAM
# - Amazon Macie
# - AWS WAF
# - Guardrails
# - Bedrock Guardrails
#
# *These topics appear in scope.*
#
# ---
#
# We'll practice:
#
# - Creating IAM users
# - Access control concepts
# - Secure AI workflow
