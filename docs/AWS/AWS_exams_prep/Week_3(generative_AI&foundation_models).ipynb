# %% [markdown]
# # Generative AI & foundation models

# %% [markdown]
# **Topics**:
#
# - Foundation Models
# - LLMs
# - Prompt Engineering
# - Context Engineering
# - Tokenization
# - RAG
# - Fine-tuning
# - In-context learning
# - Model distillation
#
# These are specifically referenced in the guide.
#
# ---
#
# **AWS services**: we'll focus on:
#
# - Amazon Bedrock
# - Bedrock agents
# - Bedrock prompt management
#
# ---
#
# **Practice**:
# PartyRock workshop where you'll build:
#   - FAQ Assistant
#   - Resume Assistant
#   - Incident Report Assistant
#
# *without coding.*
