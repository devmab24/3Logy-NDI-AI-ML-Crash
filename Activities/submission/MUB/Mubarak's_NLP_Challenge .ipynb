# %%
### 🚀 NLP Challenge

* *Live Streamlit App:* [Click here to view the Demo](https://safeops-mind-ad9nngim95q7ad9txqobya.streamlit.app/)
* *GitHub Repository:* [Click here to view the Source Code](https://github.com/mshehujrn-hub/Safeops-mind)
