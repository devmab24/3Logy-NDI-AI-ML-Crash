# %%
# Import pandas library, aliased as `pd`
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# C:\Users\Maihanci\OneDrive\Desktop\ai_ml_project\3Logy-NDI-AI-ML-Crash\Activities\week3-4_Exercise\Nasir_Armiyau_Week3-4

# %%
data = pd.read_csv("C:/Users/Maihanci/OneDrive/Desktop/ai_ml_project/3Logy-NDI-AI-ML-Crash/Activities/week3-4_Exercise/Nasir_Armiyau_Week3-4/students_200_dataset.csv")
data.head()
# Out:
#    student_id          name  age course_code  exam_score
# 0           1    John Lawal   20      STA201          89
# 1           2    John James   30      CSC101          83
# 2           3    Amina Sani   28      CSC101          83
# 3           4  David Yakubu   28      CSC101          99
# 4           5      Ali Sani   26      CSC101          85

# %%
data.to_csv("C:/Users/Maihanci/OneDrive/Desktop/ai_ml_project/3Logy-NDI-AI-ML-Crash/Activities/week3-4_Exercise/Nasir_Armiyau_Week3-4/New_Students_200_dataset.csv")

# %%
from IPython.display import Image, display

display(Image("AI-vs-machine-learning.jpg"))

# %%
#Data types
data.dtypes
# Out:
# student_id     int64
# name             str
# age            int64
# course_code      str
# exam_score     int64
# dtype: object

# %%
# This returns the column names as a list
data.columns
# Out:
# Index(['student_id', 'name', 'age', 'course_code', 'exam_score'], dtype='str')

# %%
# we created a variable called data_columns and stored our columns
data_columns = data.columns
data_columns
# Out:
# Index(['student_id', 'name', 'age', 'course_code', 'exam_score'], dtype='str')

# %%
# Index is a data structure used by Pandas to store labels for rows and columns. i.e here we've column index
data.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
#If you're interested in understanding the dimensionality of the DataFrame, we can use the df.shape method. The code looks like this:
data.shape
print("df_houses shape:", data.shape)
# Out:
# df_houses shape: (200, 5)
