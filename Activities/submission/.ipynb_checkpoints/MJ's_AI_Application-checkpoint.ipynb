# %% [markdown]
# ## Research on AI application in oil and gas

# %% [markdown]
# * *AI application in oil and gas:* [Click here to view the explanation on Notion](https://www.notion.so/AI-Transformation-in-Oil-Gas-Multimodal-Pipeline-Integrity-Asset-Management-Presentation-bce7a05bb278427ca1012d90a56ad009?source=copy_link)
# * *Presentation Slides:* [Click here to view the presentation on Canva](https://canva.link/uwji8m7zks8ymce)
