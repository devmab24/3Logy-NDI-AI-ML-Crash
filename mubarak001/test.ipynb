# %%
# IMPORT LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import joblib

# %%
# Import dataset
data = pd.read_csv(r"C:\Users\msheh\Desktop\AI_ML001\3Logy-NDI-AI-ML-Crash\datasets\telco-customer-churn1.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
import pandas as pd

# 1. Load your data
data = pd.read_csv(r"C:\Users\msheh\Desktop\AI_ML001\3Logy-NDI-AI-ML-Crash\datasets\telco-customer-churn1.csv")

# 2. Define X (features) and y (target)
# Let's say 'target_column' is what you want to predict
X = data.drop('TotalCharges', axis=1) 
y = data['TotalCharges']

# 3. NOW you can run your split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
y.head(), y.value_counts()
# Out:
# (0      29.85
#  1     1889.5
#  2     108.15
#  3    1840.75
#  4     151.65
#  Name: TotalCharges, dtype: str,
#  TotalCharges
#  20.2      11
#            11
#  19.75      9
#  19.9       8
#  20.05      8
#            ..
#  1990.5     1
#  7362.9     1
#  346.45     1
#  306.6      1
#  6844.5     1
#  Name: count, Length: 6531, dtype: int64)

# %%
# Split the data into training and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    test_size=0.25) # by default train_test_split uses 25% of the data for the test set

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5282, 20), (1761, 20), (5282,), (1761,))

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

# %%
# View the current hyperparameters
clf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
X_test.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4348  6121-VZNQB  Female              0      No         No       1
# 812   8098-TDCBU  Female              0     Yes         No      42
# 6792  4597-ELFTS    Male              0      No         No      56
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 5542  2990-OGYTD  Female              0     Yes         No      67
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 4348          Yes            No              No  No internet service
# 812           Yes           Yes              No  No internet service
# 6792          Yes           Yes              No  No internet service
# 26            Yes           Yes     Fiber optic                   No
# 5542          Yes           Yes             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 4348  No internet service  No internet service  No internet service
# ...
