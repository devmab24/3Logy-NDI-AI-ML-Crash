# %%
1+1

# %%
2+2
# Out:
# 4

# %% [markdown]
# # This is a big Heading

# %% [markdown]
# ## This is a sub heading

# %% [markdown]
# **This has been bolded**

# %% [markdown]
# This is notebook intro course using plain text

# %% [markdown]
# - This is bulletting
