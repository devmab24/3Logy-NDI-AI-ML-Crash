# %% [markdown]
# # Assignment

# %%
# import pandas library,aliased as pd
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# import dataset
data =pd.read_csv("3Logy-NDI-AI-ML-Crash/assignment data/student_records.csv")

# %%
data.head()
# Out:
#   student_id first_name last_name date_of_birth enrollment_date  \
# 0   STU-1001      Sarah    Garcia    2000-02-14      2021-03-15
# 1   STU-1002     Amelia     Jones    2002-02-02      2022-05-08
# 2   STU-1003        Mia    Martin    2000-02-12      2024-09-01
# 3   STU-1004     Olivia  Gonzalez    2006-05-02      2022-07-07
# 4   STU-1005      Emily   Johnson    2002-05-19      2022-04-02
#
#                     major   gpa           city
# 0             Mathematics  2.82  Port Harcourt
# 1      English Literature  2.56           Kano
# 2      English Literature  2.98  Port Harcourt
# 3        Computer Science  3.46          Lagos
# 4  Mechanical Engineering  3.45            Jos

# %% [markdown]
# # Anatomy of a data frame

# %%
from IPython.display import Image, display
display(Image("3Logy-NDI-AI-ML-Crash/images/malam faisal.png"))

# %%
#Data types
data.dtypes
# Out:
# student_id             str
# first_name             str
# last_name              str
# date_of_birth          str
# enrollment_date        str
# major                  str
# gpa                float64
# city                   str
# dtype: object

# %%
data.columns
# Out:
# Index(['student_id', 'first_name', 'last_name', 'date_of_birth',
#        'enrollment_date', 'major', 'gpa', 'city'],
#       dtype='str')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
data_colums = data.columns

# %%
data.shape
# Out:
# (100, 8)
