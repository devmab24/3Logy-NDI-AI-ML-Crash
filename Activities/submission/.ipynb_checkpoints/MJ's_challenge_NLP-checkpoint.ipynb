# %% [markdown]
# ### 🚀 NLP challenge on Pipeline Integrety.
#
# * **Live Streamlit App:** [Click here to view the Demo](https://corrosion-identification-c4qhyiu68ftkwhousbfvhz.streamlit.app/)
# * **GitHub Repository:** [Click here to view the Source Code](https://github.com/murjanatujaafaru-a11y/corrosion-identification)
