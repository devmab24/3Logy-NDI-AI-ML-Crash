# %% [markdown]
# ### 🚀 CNN Project
#
# * *Live Streamlit App:* [Click here to view the Demo](https://gasleak-dpv4n8ndmpnceud8gh2k2g.streamlit.app/)
# * *GitHub Repository:* [Click here to view the Source Code](https://github.com/mshehujrn-hub/Gas_leak)
