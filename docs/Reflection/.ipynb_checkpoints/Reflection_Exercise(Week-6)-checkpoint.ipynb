# %% [markdown]
# # Week 6 Reflection – AI/ML Journey
#
# This reflection will help you evaluate your progress, identify your strengths, and plan for improvement.
#
# Take your time and answer honestly.

# %% [markdown]
# ## Step 1: What Have I Learned?
#
# Think about everything we’ve covered so far.
#
# ### Topics:
# - Jupyter Notebook
# - Python Basics
# - Data Handling (Pandas)
# - Data Visualization (matplotlib)
# - Introduction to Machine Learning (scikit-learn)
# - Machine Learning models (Supervised Learning)
#
# ### Questions:
# - What topics have I learned so far?
# - What can I now do that I couldn’t do before?

# %%
#Run the cell first
learned = input("List what you have learned so far: ")
new_skills = input("What can you now do that you couldn’t do before? ")

print("\nYour Learning Summary:")
print(learned)
print(new_skills)
# Out:
# List what you have learned so far:  I have learned Jupyter Notebook, Python basics, data handling with Pandas, data visualization using Matplotlib, introduction to machine learning with Scikit-learn, supervised and unsupervised learning techniques.
# What can you now do that you couldn’t do before?  Before now I could not launch jupyter notebook, clean datasets, train machine learning models, and use Git Bash to pull and push files
# Your Learning Summary:
# I have learned Jupyter Notebook, Python basics, data handling with Pandas, data visualization using Matplotlib, introduction to machine learning with Scikit-learn, supervised and unsupervised learning techniques.
# Before now I could not launch jupyter notebook, clean datasets, train machine learning models, and use Git Bash to pull and push files

# %% [markdown]
# ## Step 2: What Can I Do Now?
#
# Complete this sentence:
#
# "Right now, I can..."
#
# List at least 5 skills.

# %%
#Run the cell to enter skills
skills = []

for i in range(5):
    skill = input(f"Enter skill {i+1}: ")
    skills.append(skill)

print("\nYour Skills:")
for s in skills:
    print("-", s)
# Out:
# Enter skill 1:  Right now i can write and run Python programs in Jupyter Notebook.
# Enter skill 2:  Analyze and clean datasets using Pandas.
# Enter skill 3:  Create charts and visualizations using Matplotlib.
# Enter skill 4:  Train and evaluate machine learning models using Scikit-learn.
# Enter skill 5:  Use Git Bash to manage and upload projects to GitHub.
# Your Skills:
# - Right now i can write and run Python programs in Jupyter Notebook.
# - Analyze and clean datasets using Pandas.
# - Create charts and visualizations using Matplotlib.
# - Train and evaluate machine learning models using Scikit-learn.
# - Use Git Bash to manage and upload projects to GitHub.

# %% [markdown]
# ## Step 3: My Strengths
#
# - Which tasks do I find easy?
# - Where do I feel confident?
# - Which assignment did I perform best in?

# %%
#Run the cell to enter strengths
strengths = input("What are your strongest areas? ")

print("\nYour Strengths:")
print(strengths)
# Out:
# What are your strongest areas?  My strongest areas are writing Python code, working with Pandas for data analysis, and creating visualizations. I also feel confident in following coding instructions and debugging simple errors.
# Your Strengths:
# My strongest areas are writing Python code, working with Pandas for data analysis, and creating visualizations. I also feel confident in following coding instructions and debugging simple errors.

# %% [markdown]
# ## Step 4: Areas for Improvement
#
# Be honest. This is how you grow.
#
# - Which topics confuse me?
# - Where do I struggle most?
# - What mistakes do I repeat?

# %%
#Run the cell to enter weakness
weakness = input("What are your weak areas? ")

print("\nAreas to Improve:")
print(weakness)
# Out:
# What are your weak areas?  My weak areas include understanding complex machine learning concepts, tuning models, and fixing advanced errors. I sometimes struggle with remembering syntax and applying concepts without guidance.
# Areas to Improve:
# My weak areas include understanding complex machine learning concepts, tuning models, and fixing advanced errors. I sometimes struggle with remembering syntax and applying concepts without guidance.

# %% [markdown]
# ## Step 5: Real-World Thinking
#
# - Can I solve any real-world problem?
# - If given a dataset, what can I do with it?
# - Can I explain AI/ML to someone else?

# %%
#Run the cell to enter real_world problem you can solve
real_world = input("Describe one problem you can solve with your current skills: ")

print("\nYour Real-World Application:")
print(real_world)
# Out:
# Describe one problem you can solve with your current skills:  I can solve problems such as predicting customer behavior or analyzing sales data. For example, I can use a dataset to predict whether a customer is likely to default on a loan or not.
# Your Real-World Application:
# I can solve problems such as predicting customer behavior or analyzing sales data. For example, I can use a dataset to predict whether a customer is likely to default on a loan or not.

# %% [markdown]
# ## Step 6: Effort & Consistency
#
# - Am I practicing regularly?
# - Do I try coding outside class?
# - Do I ask questions when I don’t understand?

# %%
#Run the cell to enter effort
effort = input("How consistent have you been in your learning? ")

print("\nYour Effort Reflection:")
print(effort)
# Out:
# How consistent have you been in your learning?  I have been fairly consistent in my learning. I attend classes, practice coding, and try to complete assignments. However, I can improve by practicing more outside of class and asking more questions when I don’t understand.
# Your Effort Reflection:
# I have been fairly consistent in my learning. I attend classes, practice coding, and try to complete assignments. However, I can improve by practicing more outside of class and asking more questions when I don’t understand.

# %% [markdown]
# ## Step 7: Improvement Plan (Next 4 Weeks)
#
# Complete this:
#
# "In the next 4 weeks, I will..."

# %%
#Run the cell to enter your improv. plan
plan = input("What will you improve in the next 4 weeks? ")

print("\nYour Plan:")
print(plan)
# Out:
# What will you improve in the next 4 weeks?  In the next 4 weeks, I will practice coding daily, revise Python and Pandas concepts, work on more datasets, improve my understanding of machine learning models, and build at least one small project.
# Your Plan:
# In the next 4 weeks, I will practice coding daily, revise Python and Pandas concepts, work on more datasets, improve my understanding of machine learning models, and build at least one small project.

# %% [markdown]
# ## Step 8: Motivation
#
# - Why did I join this program?
# - What do I want to become?

# %%
motivation = input("Why did you start this journey? ")

print("\nYour Motivation:")
print(motivation)
# Out:
# Why did you start this journey?  I started this journey to gain valuable tech skills and build a career in AI/ML. I want to become a data scientist or machine learning engineer and use my skills to solve real-world problems.
# Your Motivation:
# I started this journey to gain valuable tech skills and build a career in AI/ML. I want to become a data scientist or machine learning engineer and use my skills to solve real-world problems.

# %% [markdown]
# # Final Reflection
# You have completed your Week 6 reflection.
#
# **Remember**:
# - You started as a beginner. Now you can already build real things.
#
# NOTE: Stay consistent. Keep practicing. You are progressing.
