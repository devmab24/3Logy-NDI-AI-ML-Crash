# %% [markdown]
# Week 6 Reflection – AI/ML Journey
# This reflection will help you evaluate your progress, identify your strengths, and plan for improvement.
#
# Take your time and answer honestly.

# %% [markdown]
# Step 1: What Have I Learned?
# Think about everything we’ve covered so far.
#
# Topics:
# Jupyter Notebook
# Python Basics
# Data Handling (Pandas)
# Data Visualization (matplotlib)
# Introduction to Machine Learning (scikit-learn)
# Machine Learning models (Supervised Learning)
# Questions:
# What topics have I learned so far?
# What can I now do that I couldn’t do before?

# %%
#Run the cell first:
learned = "Jupyter Notebook, Python basics (variables, loops, conditions, functions), Pandas for data handling, matplotlib for data visualization, introduction to machine learning, and supervised learning using scikit-learn"

new_skills = "I can now write Python programs, clean and analyze datasets, create visualizations like charts and graphs, train simple machine learning models, and make predictions using scikit-learn"

print("\nYour Learning Summary:")
print(learned)
print(new_skills)
# Out:
# Your Learning Summary:
# Jupyter Notebook, Python basics (variables, loops, conditions, functions), Pandas for data handling, matplotlib for data visualization, introduction to machine learning, and supervised learning using scikit-learn
# I can now write Python programs, clean and analyze datasets, create visualizations like charts and graphs, train simple machine learning models, and make predictions using scikit-learn

# %%
skills = [
    "Write and run Python programs in Jupyter Notebook",
    "Load, clean, and manipulate datasets using Pandas",
    "Create data visualizations using matplotlib",
    "Train and test supervised machine learning models",
    "Use scikit-learn for predictions and basic model evaluation"
]

print("\nYour Skills:")
for s in skills:
    print("-", s)
# Out:
# Your Skills:
# - Write and run Python programs in Jupyter Notebook
# - Load, clean, and manipulate datasets using Pandas
# - Create data visualizations using matplotlib
# - Train and test supervised machine learning models
# - Use scikit-learn for predictions and basic model evaluation

# %%
#Run the cell to enter strengths
strengths = [
    "Understanding Python basics and writing simple programs",
    "Working with Pandas for data cleaning and analysis",
    "Creating visualizations using matplotlib",
    "Explaining concepts to classmates and helping others",
    "Performing best in data analysis and visualization assignments"
]

print("\nYour Strengths:")
for s in strengths:
    print("-", s)
# Out:
# Your Strengths:
# - Understanding Python basics and writing simple programs
# - Working with Pandas for data cleaning and analysis
# - Creating visualizations using matplotlib
# - Explaining concepts to classmates and helping others
# - Performing best in data analysis and visualization assignments

# %%
#Run the cell to enter weakness
weakness = "Understanding advanced machine learning concepts, choosing the right algorithm for different problems, struggling with model evaluation, occasional syntax errors, and repeating mistakes like forgetting functions or imports"

print("\nAreas to Improve:")
print(weakness)
# Out:
# Areas to Improve:
# Understanding advanced machine learning concepts, choosing the right algorithm for different problems, struggling with model evaluation, occasional syntax errors, and repeating mistakes like forgetting functions or imports

# %%
#Run the cell to enter real_world problem you can solve
real_world = "I can analyze datasets such as student performance or sales data, clean the data, visualize trends, and build simple machine learning models to make predictions and generate useful insights."

print("\nYour Real-World Application:")
print(real_world)
# Out:
# Your Real-World Application:
# I can analyze datasets such as student performance or sales data, clean the data, visualize trends, and build simple machine learning models to make predictions and generate useful insights.

# %%
#Run the cell to enter effort
effort = "I have been fairly consistent in my learning, practicing during class and sometimes outside class. I try to solve coding problems on my own, but I need to improve by practicing more regularly and asking more questions when I get stuck."

print("\nYour Effort Reflection:")
print(effort)
# Out:
# Your Effort Reflection:
# I have been fairly consistent in my learning, practicing during class and sometimes outside class. I try to solve coding problems on my own, but I need to improve by practicing more regularly and asking more questions when I get stuck.

# %%
#Run the cell to enter your improv. plan
plan = "In the next 4 weeks, I will practice coding daily, work more on real-world datasets, improve my understanding of machine learning concepts, learn how to properly evaluate models, and build at least one complete mini project using Python and scikit-learn."

print("\nYour Plan:")
print(plan)
# Out:
# Your Plan:
# In the next 4 weeks, I will practice coding daily, work more on real-world datasets, improve my understanding of machine learning concepts, learn how to properly evaluate models, and build at least one complete mini project using Python and scikit-learn.

# %%
motivation = "I started this journey to gain strong skills in Python, data science, and machine learning, so I can build real-world solutions, analyze data effectively, and grow into a skilled data analyst and machine learning practitioner."

print("\nYour Motivation:")
print(motivation)
# Out:
# Your Motivation:
# I started this journey to gain strong skills in Python, data science, and machine learning, so I can build real-world solutions, analyze data effectively, and grow into a skilled data analyst and machine learning practitioner.
