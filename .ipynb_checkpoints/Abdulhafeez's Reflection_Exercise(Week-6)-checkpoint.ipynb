# %% [markdown]
# # Week 6 Reflection – AI/ML Journey
#
# This reflection will help you evaluate your progress, identify your strengths, and plan for improvement.
#
# Take your time and answer honestly.

# %% [markdown]
# ## Step 1: What Have I Learned?
#
# Think about everything we’ve covered so far.
#
# ### Topics:
# - Jupyter Notebook
# - Python Basics
# - Data Handling (Pandas)
# - Data Visualization (matplotlib)
# - Introduction to Machine Learning (scikit-learn)
# - Machine Learning models (Supervised Learning)
#
# ### Questions:
# - What topics have I learned so far?
# - What can I now do that I couldn’t do before?

# %%
#Run the cell first
learned = input("1_AI/ML Foundations (Introduction), 2_Understand AI/ML: Tools setup, 3_Python Basics; Python basics, Data preprocessing, tools (Jupyter Notebook, Pandas, Python), 4_Machine Learning Basics supervised Learning and unsupervised Learning: ")
new_skills = input("1_I can now use basic python functions 2_i can use pandas and matplotlib for data manipulation and visualisation 3_I can train a basic supervised and unsupervised ML model 4_ i can intaract with github using bash  ")

print("\nYour Learning Summary:")
print(learned)
print(new_skills)
# Out:
# 1_AI/ML Foundations (Introduction), 2_Understand AI/ML: Tools setup, 3_Python Basics; Python basics, Data preprocessing, tools (Jupyter Notebook, Pandas, Python), 4_Machine Learning Basics supervised Learning and unsupervised Learning:  1
# 1_I can now use basic python functions 2_i can use pandas and matplotlib for data manipulation and visualisation 3_I can train a basic supervised and unsupervised ML model 4_ i can intaract with github using bash   1
# Your Learning Summary:
# 1
# 1

# %% [markdown]
# ## Step 2: What Can I Do Now?
#
# Complete this sentence:
#
# "Right now, I can..."
#
# List at least 5 skills.

# %%
#Run the cell to enter skills
skills = [ "write a basic python code", "use pandas and matplotlib for data", "train a basic supervised", "train an unsupervised ml model", "interact with github throug bash:"]

for i in range(5):
    skill = input(f"Enter skill {i+1}: ")
    skills.append(skill)

print("\nYour Skills:")
for s in skills:
    print("-", s)
# Out:
# Enter skill 1:  1
# Enter skill 2:  1
# Enter skill 3:  1
# Enter skill 4:  1
# Enter skill 5:  1
# Your Skills:
# - write a basic python code
# - use pandas and matplotlib for data
# - train a basic supervised
# - train an unsupervised ml model
# - interact with github throug bash:
# - 1
# - 1
# - 1
# - 1
# - 1

# %% [markdown]
# ## Step 3: My Strengths
#
# - Which tasks do I find easy?
# - Where do I feel confident?
# - Which assignment did I perform best in?

# %%
#Run the cell to enter strengths
strengths = input("(1_pandas, 2_scikitlearn, 3_gitbash): ")

print("\nYour Strengths:")
print(strengths)
# Out:
# (1_pandas, 2_scikitlearn, 3_gitbash):  1
# Your Strengths:
# 1

# %% [markdown]
# ## Step 4: Areas for Improvement
#
# Be honest. This is how you grow.
#
# - Which topics confuse me?
# - Where do I struggle most?
# - What mistakes do I repeat?

# %%
#Run the cell to enter weakness
weakness = input("i am still weak in all. ")

print("\nAreas to Improve:")
print(weakness)
# Out:
# i am still weak in all.  1
# Areas to Improve:
# 1

# %% [markdown]
# ## Step 5: Real-World Thinking
#
# - Can I solve any real-world problem?
# - If given a dataset, what can I do with it?
# - Can I explain AI/ML to someone else?

# %%
#Run the cell to enter real_world problem you can solve
real_world = input("using my skills i can train a ML model to predict house prices ")

print("\nYour Real-World Application:")
print(real_world)
# Out:
# using my skills i can train a ML model to predict house prices  1
# Your Real-World Application:
# 1

# %% [markdown]
# ## Step 6: Effort & Consistency
#
# - Am I practicing regularly?
# - Do I try coding outside class?
# - Do I ask questions when I don’t understand?

# %%
#Run the cell to enter effort
effort = input("i am not as consisten as i should be, but i will put in more effort. ")

print("\nYour Effort Reflection:")
print(effort)
# Out:
# i am not as consisten as i should be, but i will put in more effort.  1
# Your Effort Reflection:
# 1

# %% [markdown]
# ## Step 7: Improvement Plan (Next 4 Weeks)
#
# Complete this:
#
# "In the next 4 weeks, I will..."

# %%
#Run the cell to enter your improv. plan
plan = input("i wan to improve my knowledge of python in general ")

print("\nYour Plan:")
print(plan)
# Out:
# i wan to improve my knowledge of python in general  1
# Your Plan:
# 1

# %% [markdown]
# ## Step 8: Motivation
#
# - Why did I join this program?
# - What do I want to become?

# %%
motivation = input("i am still conflicted about this but i am sure it will not distract or interfare with my learning and improvment ")

print("\nYour Motivation:")
print(motivation)
# Out:
# i am still conflicted about this but i am sure it will not distract or interfare with my learning and improvment  1
# Your Motivation:
# 1

# %% [markdown]
# # Final Reflection
# You have completed your Week 6 reflection.
#
# **Remember**:
# - You started as a beginner. Now you can already build real things.
#
# NOTE: Stay consistent. Keep practicing. You are progressing.
