# %% [markdown]
# This project will keep evolving throughout the course giving students the feeling that they're working on a **real product**, not just completing disconnected exercises. By the end of the project, you'll have something you're genuinely proud to showcase on GitHub and LinkedIn.
#
# A professional product name:
#
# ### Smart Incident Report Analyzer (SIRA)
#
# **Tagline:**
#
# > *An AI-powered platform for analyzing, classifying, and managing incident reports in the Oil & Gas industry.*
#
# ---
#
# ## Course Roadmap
#
# ### Phase 1 - Software Engineering Foundations
#
# Students build the project's backbone.
#
# ✔ Python Modules
#
# ✔ Packages
#
# ✔ OOP
#
# ✔ Project Structure
#
# ---
#
# ### Phase 2 - Data Engineering
#
# Students learn how data enters the system.
#
# ✔ Read CSV
#
# ✔ Load Data
#
# ✔ Validate Data
#
# ✔ Clean Data
#
# ✔ Exploratory Data Analysis
#
# ---
#
# ### Phase 3 - Machine Learning
#
# Students build the first ML model.
#
# ✔ Feature Engineering
#
# ✔ Train/Test Split
#
# ✔ TF-IDF
#
# ✔ Model Training
#
# ✔ Model Evaluation
#
# ✔ Model Saving
#
# ---
#
# ### Phase 4 - AI Integration
#
# Students improve the system.
#
# ✔ Hugging Face Models
#
# ✔ Summarization
#
# ✔ Named Entity Recognition
#
# ✔ Severity Classification
#
# ✔ Explainability
#
# ---
#
# ### Phase 5 - Deployment
#
# Students build an application.
#
# ✔ Streamlit
#
# ✔ API
#
# ✔ Docker
#
# ✔ AWS
#
# ✔ SageMaker
#
# ---
#
# ## Project Architecture
#
# Eventually, the project will look like this:
#
# ```text
# smart_incident_report_analyzer/
#
# │
# ├── data/
# │   ├── raw/
# │   ├── processed/
# │   └── external/
# │
# ├── notebooks/
# │   ├── 01_python_to_ml_engineering.ipynb
# │   ├── 02_data_loading.ipynb
# │   ├── 03_preprocessing.ipynb
# │   ├── 04_feature_engineering.ipynb
# │   ├── 05_model_training.ipynb
# │   ├── 06_model_evaluation.ipynb
# │   └── 07_deployment.ipynb
# │
# ├── src/
# │   ├── __init__.py
# │   ├── config.py
# │   ├── data_loader.py
# │   ├── preprocessing.py
# │   ├── feature_engineering.py
# │   ├── trainer.py
# │   ├── evaluator.py
# │   ├── predictor.py
# │   ├── visualization.py
# │   └── utils.py
# │
# ├── models/
# │   ├── incident_classifier.pkl
# │   ├── tfidf_vectorizer.pkl
# │   └── metrics.json
# │
# ├── reports/
# │   ├── figures/
# │   └── evaluation_report.md
# │
# ├── tests/
# │   ├── test_data_loader.py
# │   ├── test_preprocessing.py
# │   └── test_predictor.py
# │
# ├── app.py
# ├── train.py
# ├── requirements.txt
# ├── README.md
# ├── .gitignore
# └── LICENSE
# ```
#
# This mirrors the organization of many professional ML repositories.
#
# ---
#
# # How we'll build It
#
# The project won't appear all at once. We'll create it incrementally.
#
# ### Notebook 1
#
# Create:
#
# ```text
# smart_incident_report_analyzer/
#
# ├── notebooks/
# ├── src/
# ├── data/
# ├── models/
# ├── README.md
# └── requirements.txt
# ```
#
# No ML yet.
#
# Just structure.
#
# ---
#
# ### Notebook 2
#
# Create:
#
# ```text
# src/
#     data_loader.py
# ```
#
# Learn:
#
# * Modules
# * Imports
# * Functions
# * Reading CSV
#
# ---
#
# ### Notebook 3
#
# Create:
#
# ```text
# src/
#     preprocessing.py
# ```
#
# Learn:
#
# * Text Cleaning
# * Functions
# * Regular Expressions
#
# ---
#
# ### Notebook 4
#
# Create:
#
# ```text
# src/
#     trainer.py
# ```
#
# Train the first model.
#
# ---
#
# ### Notebook 5
#
# Create:
#
# ```text
# src/
#     predictor.py
# ```
#
# Make predictions.
#
# ---
#
# ### Notebook 6
#
# Create:
#
# ```text
# app.py
# ```
#
# Deploy with Streamlit.
#
# ---
#
# ### Notebook 7
#
# Deploy to AWS.
#
# ---
#
# # What you'll learn without realizing it
#
# While you think you're "just building a project," you'll naturally absorb professional development practices:
#
# * Python modules
# * Packages
# * Imports
# * OOP
# * Separation of concerns
# * Configuration management
# * Project organization
# * Version control with Git
# * Documentation
# * Dependency management
# * Testing
# * Deployment
#
# By the time you start using Scikit-learn, concepts like:
#
# ```python
# from sklearn.linear_model import LogisticRegression
#
# model = LogisticRegression()
# model.fit(X_train, y_train)
# ```
#
# will feel intuitive because you'll already understand:
#
# * packages (`sklearn`)
# * modules (`linear_model`)
# * classes (`LogisticRegression`)
# * objects (`model`)
# * methods (`fit`)
#
# ---
# Note: *"Professional AI Engineers spend a significant amount of time designing and organizing projects before training their first model. A well-structured project is easier to develop, test, maintain, and extend."*
