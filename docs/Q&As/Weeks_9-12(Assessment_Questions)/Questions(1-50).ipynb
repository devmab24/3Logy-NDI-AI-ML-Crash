# %% [markdown]
# # AI/ML professional preparation series
# # Weeks 9-12
#
# ## Topics covered
# - Natural Language Processing (NLP)
# - NLTK, SpaCy, Gensim
# - Text Preprocessing
# - Sentiment Analysis
# - Named Entity Recognition (NER)
# - Hugging Face Models
# - Streamlit Deployment
# - FastAPI Basics
# - AI in Oil & Gas
# - Predictive Maintenance
# - Reservoir Characterization
# - Seismic Data Analysis
# - Industry-Specific AI Solutions
#
# ---
#
# ## Instructions
#
# - Attempt each question before checking the answer.
# - Click the dropdown arrow to reveal the answer.
# - Some questions are practical and scenario-based.
# - Focus on understanding and application.

# %% [markdown]
# ---
# # Beginner questions
# ---

# %% [markdown]
# ### 1. What is natural language processing (NLP)?
#
# <details>
# <summary>Show Answer</summary>
#
# NLP is a branch of AI that enables computers to understand, process, and analyze human language.
#
# </details>
#
# ---
#
# ### 2. Mention two applications of NLP.
#
# <details>
# <summary>Show Answer</summary>
#
# - Chatbots
# - Sentiment Analysis
#
# </details>
#
# ---
#
# ### 3. What is text preprocessing?
#
# <details>
# <summary>Show Answer</summary>
#
# Text preprocessing is the process of cleaning and preparing text data before analysis or model training.
#
# </details>
#
# ---
#
# ### 4. What is tokenization?
#
# <details>
# <summary>Show Answer</summary>
#
# Tokenization splits text into smaller units such as words or sentences.
#
# </details>
#
# ---
#
# ### 5. What is stopword removal?
#
# <details>
# <summary>Show Answer</summary>
#
# Stopword removal removes common words like "the", "is", and "and" that may not add meaning.
#
# </details>
#
# ---
#
# ### 6. What is stemming?
#
# <details>
# <summary>Show Answer</summary>
#
# Stemming reduces words to their root form.
#
# </details>
#
# ---
#
# ### 7. What is lemmatization?
#
# <details>
# <summary>Show Answer</summary>
#
# Lemmatization converts words into their meaningful base form.
#
# </details>
#
# ---
#
# ### 8. What is sentiment analysis?
#
# <details>
# <summary>Show Answer</summary>
#
# Sentiment analysis identifies emotional tone in text such as positive, negative, or neutral.
#
# </details>
#
# ---
#
# ### 9. What is named entity recognition (NER)?
#
# <details>
# <summary>Show Answer</summary>
#
# NER identifies entities such as names, locations, and organizations in text.
#
# </details>
#
# ---
#
# ### 10. Mention one NLP library.
#
# <details>
# <summary>Show Answer</summary>
#
# NLTK, SpaCy, or Gensim.
#
# </details>
#
# ---
#
# ### 11. What is hugging face?
#
# <details>
# <summary>Show Answer</summary>
#
# Hugging Face is a platform providing pretrained AI models and NLP tools.
#
# </details>
#
# ---
#
# ### 12. What is a pretrained model?
#
# <details>
# <summary>Show Answer</summary>
#
# A pretrained model is a model already trained on large datasets and reused for new tasks.
#
# </details>
#
# ---
#
# ### 13. What is streamlit?
#
# <details>
# <summary>Show Answer</summary>
#
# Streamlit is a Python framework for building interactive AI and data applications.
#
# </details>
#
# ---
#
# ### 14. Why is Streamlit useful in AI projects?
#
# <details>
# <summary>Show Answer</summary>
#
# It allows quick deployment of Machine Learning applications with simple code.
#
# </details>
#
# ---
#
# ### 15. What is FastAPI?
#
# <details>
# <summary>Show Answer</summary>
#
# FastAPI is a modern Python framework used for building APIs.
#
# </details>
#
# ---
#
# ### 16. What is deployment in AI?
#
# <details>
# <summary>Show Answer</summary>
#
# Deployment is the process of making AI models available for real-world use.
#
# </details>
#
# ---
#
# ### 17. What is predictive maintenance?
#
# <details>
# <summary>Show Answer</summary>
#
# Predictive maintenance uses AI to predict equipment failure before it happens.
#
# </details>
#
# ---
#
# ### 18. Mention one AI application in Oil & Gas.
#
# <details>
# <summary>Show Answer</summary>
#
# Predictive maintenance, PPE detection, or seismic analysis.
#
# </details>
#
# ---
#
# ### 19. What is reservoir characterization?
#
# <details>
# <summary>Show Answer</summary>
#
# Reservoir characterization is the analysis of underground reservoirs to understand rock and fluid properties.
#
# </details>
#
# ---
#
# ### 20. What is seismic data analysis?
#
# <details>
# <summary>Show Answer</summary>
#
# Seismic data analysis interprets underground geological structures using reflected sound waves.
#
# </details>

# %% [markdown]
# ---
#
# # Intermediate questions
#
# ---

# %% [markdown]
# ### 21. Why is text preprocessing important in NLP?
#
# <details>
# <summary>Show Answer</summary>
#
# It improves data quality and model performance.
#
# </details>
#
# ---
#
# ### 22. Differentiate between stemming and lemmatization.
#
# <details>
# <summary>Show Answer</summary>
#
# Stemming cuts words mechanically, while lemmatization converts them into meaningful base forms.
#
# </details>
#
# ---
#
# ### 23. Explain how sentiment analysis can help businesses.
#
# <details>
# <summary>Show Answer</summary>
#
# It helps analyze customer opinions and feedback.
#
# </details>
#
# ---
#
# ### 24. How can NLP help the Oil & Gas industry?
#
# <details>
# <summary>Show Answer</summary>
#
# NLP can analyze incident reports, maintenance logs, and operational documents.
#
# </details>
#
# ---
#
# ### 25. What is model inference?
#
# <details>
# <summary>Show Answer</summary>
#
# Inference is the process of making predictions using a trained model.
#
# </details>
#
# ---
#
# ### 26. Why are pretrained models useful?
#
# <details>
# <summary>Show Answer</summary>
#
# They save training time and improve performance.
#
# </details>
#
# ---
#
# ### 27. Explain the role of APIs in AI deployment.
#
# <details>
# <summary>Show Answer</summary>
#
# APIs allow applications to communicate with AI models and receive predictions.
#
# </details>
#
# ---
#
# ### 28. What is a requirements.txt file?
#
# <details>
# <summary>Show Answer</summary>
#
# A requirements.txt file contains project dependencies needed for deployment.
#
# </details>
#
# ---
#
# ### 29. Why is GitHub important in AI projects?
#
# <details>
# <summary>Show Answer</summary>
#
# GitHub helps with version control, collaboration, and project management.
#
# </details>
#
# ---
#
# ### 30. Explain transfer learning in NLP.
#
# <details>
# <summary>Show Answer</summary>
#
# Transfer learning uses pretrained language models for new NLP tasks.
#
# </details>
#
# ---
#
# ### 31. What is DistilBERT?
#
# <details>
# <summary>Show Answer</summary>
#
# DistilBERT is a smaller and faster version of the BERT language model.
#
# </details>
#
# ---
#
# ### 32. What is fine-tuning in Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# Fine-tuning adapts a pretrained model to a specific task or dataset.
#
# </details>
#
# ---
#
# ### 33. Explain one use case of Computer Vision in Oil & Gas.
#
# <details>
# <summary>Show Answer</summary>
#
# PPE detection systems monitor worker safety compliance.
#
# </details>
#
# ---
#
# ### 34. What is PPE detection?
#
# <details>
# <summary>Show Answer</summary>
#
# PPE detection identifies whether workers are wearing safety equipment.
#
# </details>
#
# ---
#
# ### 35. Why is predictive maintenance important?
#
# <details>
# <summary>Show Answer</summary>
#
# It reduces downtime, improves safety, and lowers maintenance costs.
#
# </details>
#
# ---
#
# ### 36. Explain one challenge in deploying AI systems.
#
# <details>
# <summary>Show Answer</summary>
#
# Dependency conflicts or missing libraries can cause deployment failures.
#
# </details>
#
# ---
#
# ### 37. What is sensor data?
#
# <details>
# <summary>Show Answer</summary>
#
# Sensor data is information collected from monitoring devices.
#
# </details>
#
# ---
#
# ### 38. Why is data quality important in industrial AI systems?
#
# <details>
# <summary>Show Answer</summary>
#
# Poor-quality data can lead to inaccurate predictions and unsafe decisions.
#
# </details>
#
# ---
#
# ### 39. Explain the purpose of Streamlit dashboards.
#
# <details>
# <summary>Show Answer</summary>
#
# They provide interactive interfaces for AI applications.
#
# </details>
#
# ---
#
# ### 40. What is object detection?
#
# <details>
# <summary>Show Answer</summary>
#
# Object detection identifies and locates objects in images or videos.
#
# </details>

# %% [markdown]
# ---
#
# # Advance questions
#
# ---

# %% [markdown]
# ### 41. A company wants to analyze thousands of incident reports automatically. Which AI field is most suitable?
#
# <details>
# <summary>Show Answer</summary>
#
# Natural Language Processing (NLP).
#
# </details>
#
# ---
#
# ### 42. Why are Hugging Face models important in modern AI development?
#
# <details>
# <summary>Show Answer</summary>
#
# They provide powerful pretrained models that reduce development time.
#
# </details>
#
# ---
#
# ### 43. Explain one ethical concern in industrial AI systems.
#
# <details>
# <summary>Show Answer</summary>
#
# Incorrect predictions could affect safety and decision-making.
#
# </details>
#
# ---
#
# ### 44. Why is deployment considered one of the most important stages in AI engineering?
#
# <details>
# <summary>Show Answer</summary>
#
# Because deployment makes AI systems usable in real-world environments.
#
# </details>
#
# ---
#
# ### 45. A model works perfectly locally but fails during deployment. Mention one possible reason.
#
# <details>
# <summary>Show Answer</summary>
#
# Missing dependencies in requirements.txt.
#
# </details>
#
# ---
#
# ### 46. Why is FastAPI useful for Machine Learning systems?
#
# <details>
# <summary>Show Answer</summary>
#
# It helps expose AI models through APIs for real-world applications.
#
# </details>
#
# ---
#
# ### 47. How can AI improve safety in the Oil & Gas industry?
#
# <details>
# <summary>Show Answer</summary>
#
# AI can detect hazards, monitor PPE compliance, and predict failures.
#
# </details>
#
# ---
#
# ### 48. Explain one challenge of seismic data analysis.
#
# <details>
# <summary>Show Answer</summary>
#
# Seismic data is large and complex, requiring significant computation and expertise.
#
# </details>
#
# ---
#
# ### 49. Why is fine-tuning better than training from scratch for many beginners?
#
# <details>
# <summary>Show Answer</summary>
#
# Fine-tuning requires less data, time, and computational resources.
#
# </details>
#
# ---
#
# ### 50. If you were building an AI solution for Oil & Gas today, what would you build and why?
#
# <details>
# <summary>Show Answer</summary>
#
# Possible answers include PPE detection, predictive maintenance, incident analysis, or leak detection because they improve operational efficiency and safety.
#
# </details>
#
# ---
#
# # Reflection questions
#
# 1. Which AI deployment concept interests you most?
# 2. Which NLP topic do you still struggle with?
# 3. What industry AI solution would you like to build?
# 4. How can AI improve workplace safety?
# 5. Which AI specialization interests you most now?
#
# ---
#
# # Mini mock assessment
#
# 1. Define NLP.
# 2. What is tokenization?
# 3. Explain sentiment analysis.
# 4. What is predictive maintenance?
# 5. What is Streamlit used for?
# 6. Explain FastAPI.
# 7. What is fine-tuning?
# 8. Why is deployment important?
# 9. What is PPE detection?
# 10. State one AI use case in Oil & Gas.
