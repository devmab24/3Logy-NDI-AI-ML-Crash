# %%
import numpy as np

# %%
>>> np.array[0] = 10 
>>> np.array
np.array([10, 2, 3, 4, 5, 6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 np.array[0] = 10
#       2 np.array
#       3 np.array([10, 2, 3, 4, 5, 6])
#
# TypeError: 'builtin_function_or_method' object does not support item assignment
