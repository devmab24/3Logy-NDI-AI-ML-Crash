# %% [markdown]
# # AI/ML professional preparation series
#
# ## Weeks 1-4
#
# ### Topics covered
# - Introduction to AI
# - Machine Learning Fundamentals
# - Data Science Basics
# - Python for AI/ML
# - Data Preprocessing
# - Supervised vs Unsupervised Learning
# - Model Evaluation
#
# ---
#
# ## Instructions
#
# - Attempt each question before checking the answer.
# - Click the dropdown arrow to reveal the answer.
# - Think critically and explain concepts in your own words.
# - Some questions are scenario-based.
# - Some require practical reasoning
# - Difficulty increases gradually
#
# ---
#
# ## Difficulty breakdown
#
# - Beginner: 20 Questions
# - Intermediate: 20 Questions
# - Advanced: 10 Questions

# %% [markdown]
# ---
# ## SECTION A - Beginner questions
# ---

# %% [markdown]
# ### 1. What is Artificial Intelligence (AI)?
#
# <details>
# <summary>Show Answer</summary>
#
# Artificial Intelligence is the simulation of human intelligence by machines to perform tasks such as learning, reasoning, and decision-making.
#
# </details>
#
# ---
#
# ### 2. Define Machine Learning.
#
# <details>
# <summary>Show Answer</summary>
#
# Machine Learning is a branch of AI that enables computers to learn patterns from data and make predictions without being explicitly programmed.
#
# </details>
#
# ---
#
# ### 3. What is the difference between AI and Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# AI is the broader concept of machines simulating intelligence, while Machine Learning is a subset of AI focused on learning from data.
#
# </details>
#
# ---
#
# ### 4. Mention three real-world applications of AI.
#
# <details>
# <summary>Show Answer</summary>
#
# - Chatbots
# - Recommendation systems
# - Facial recognition
#
# </details>
#
# ---
#
# ### 5. What is a dataset?
#
# <details>
# <summary>Show Answer</summary>
#
# A dataset is a collection of related data used for analysis or training Machine Learning models.
#
# </details>
#
# ---
#
# ### 6. What is a feature in Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# A feature is an input variable used by a model to make predictions.
#
# </details>
#
# ---
#
# ### 7. What is a label or target variable?
#
# <details>
# <summary>Show Answer</summary>
#
# The label is the output the model tries to predict.
#
# </details>
#
# ---
#
# ### 8. Explain supervised learning.
#
# <details>
# <summary>Show Answer</summary>
#
# Supervised learning uses labeled data to train models to predict outputs from inputs.
#
# </details>
#
# ---
#
# ### 9. Explain unsupervised learning.
#
# <details>
# <summary>Show Answer</summary>
#
# Unsupervised learning works with unlabeled data to identify patterns or groupings.
#
# </details>
#
# ---
#
# ### 10. State two examples of supervised learning algorithms.
#
# <details>
# <summary>Show Answer</summary>
#
# - Linear Regression
# - Decision Tree
#
# </details>
#
# ---
#
# ### 11. What is classification in Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# Classification predicts categories or labels.
#
# </details>
#
# ---
#
# ### 12. What is regression in Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# Regression predicts continuous numerical values.
#
# </details>
#
# ---
#
# ### 13. What is Python?
#
# <details>
# <summary>Show Answer</summary>
#
# Python is a high-level programming language widely used in AI, Data Science, and software development.
#
# </details>
#
# ---
#
# ### 14. Why is Python popular in AI and Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# Because it is simple, beginner-friendly, and has powerful libraries like NumPy, Pandas, and Scikit-learn.
#
# </details>
#
# ---
#
# ### 15. What is Jupyter Notebook?
#
# <details>
# <summary>Show Answer</summary>
#
# Jupyter Notebook is an interactive environment for writing and running code, visualizations, and documentation.
#
# </details>
#
# ---
#
# ### 16. Mention two advantages of using Jupyter Notebook.
#
# <details>
# <summary>Show Answer</summary>
#
# - Interactive coding
# - Combines code and documentation in one place
#
# </details>
#
# ---
#
# ### 17. What is NumPy used for?
#
# <details>
# <summary>Show Answer</summary>
#
# NumPy is used for numerical computing and array operations.
#
# </details>
#
# ---
#
# ### 18. What is Pandas used for?
#
# <details>
# <summary>Show Answer</summary>
#
# Pandas is used for data manipulation and analysis.
#
# </details>
#
# ---
#
# ### 19. What is data preprocessing?
#
# <details>
# <summary>Show Answer</summary>
#
# Data preprocessing involves cleaning and preparing data before training a model.
#
# </details>
#
# ---
#
# ### 20. Why is data cleaning important?
#
# <details>
# <summary>Show Answer</summary>
#
# Because poor-quality data can reduce model accuracy and performance.
#
# </details>

# %% [markdown]
# ---
# # SECTION B: Intermediate Questions
# ---

# %% [markdown]
# ### 21. Differentiate between structured and unstructured data.
#
# <details>
# <summary>Show Answer</summary>
#
# Structured data is organized in tables or rows, while unstructured data includes text, images, audio, and videos.
#
# </details>
#
# ---
#
# ### 22. What is missing data? How can it affect a model?
#
# <details>
# <summary>Show Answer</summary>
#
# Missing data refers to empty or unavailable values. It can reduce model accuracy and introduce bias.
#
# </details>
#
# ---
#
# ### 23. Explain train-test split.
#
# <details>
# <summary>Show Answer</summary>
#
# Train-test split divides data into training and testing sets for model evaluation.
#
# </details>
#
# ---
#
# ### 24. Why do we split data into training and testing sets?
#
# <details>
# <summary>Show Answer</summary>
#
# To evaluate how well the model performs on unseen data.
#
# </details>
#
# ---
#
# ### 25. What is overfitting?
#
# <details>
# <summary>Show Answer</summary>
#
# Overfitting occurs when a model learns training data too well and performs poorly on new data.
#
# </details>
#
# ---
#
# ### 26. What is underfitting?
#
# <details>
# <summary>Show Answer</summary>
#
# Underfitting occurs when a model fails to learn patterns from the data properly.
#
# </details>
#
# ---
#
# ### 27. State one difference between classification and clustering.
#
# <details>
# <summary>Show Answer</summary>
#
# Classification uses labeled data, while clustering groups unlabeled data.
#
# </details>
#
# ---
#
# ### 28. What is feature engineering?
#
# <details>
# <summary>Show Answer</summary>
#
# Feature engineering is the process of creating or selecting useful input features for Machine Learning models.
#
# </details>
#
# ---
#
# ### 29. What is normalization in Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# Normalization scales data values into a similar range.
#
# </details>
#
# ---
#
# ### 30. What is the purpose of model evaluation?
#
# <details>
# <summary>Show Answer</summary>
#
# To measure how well a model performs.
#
# </details>
#
# ---
#
# ### 31. What is accuracy in Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# Accuracy measures how many predictions were correct.
#
# </details>
#
# ---
#
# ### 32. What is bias in AI?
#
# <details>
# <summary>Show Answer</summary>
#
# Bias occurs when a model unfairly favors certain outcomes due to skewed data or assumptions.
#
# </details>
#
# ---
#
# ### 33. What is an algorithm?
#
# <details>
# <summary>Show Answer</summary>
#
# An algorithm is a set of rules or steps used to solve a problem.
#
# </details>
#
# ---
#
# ### 34. Explain the role of data in Machine Learning.
#
# <details>
# <summary>Show Answer</summary>
#
# Data is used to train models and help them learn patterns.
#
# </details>
#
# ---
#
# ### 35. What happens if poor-quality data is used to train a model?
#
# <details>
# <summary>Show Answer</summary>
#
# The model may produce inaccurate or unreliable predictions.
#
# </details>
#
# ---
#
# ### 36. Explain the Machine Learning workflow.
#
# <details>
# <summary>Show Answer</summary>
#
# Data Collection → Data Cleaning → Feature Engineering → Model Training → Evaluation → Deployment.
#
# </details>
#
# ---
#
# ### 37. Why is feature selection important?
#
# <details>
# <summary>Show Answer</summary>
#
# It improves model performance and reduces unnecessary complexity.
#
# </details>
#
# ---
#
# ### 38. What is exploratory data analysis (EDA)?
#
# <details>
# <summary>Show Answer</summary>
#
# EDA involves analyzing and visualizing data to understand patterns and relationships.
#
# </details>
#
# ---
#
# ### 39. Explain the difference between dependent and independent variables.
#
# <details>
# <summary>Show Answer</summary>
#
# Independent variables are inputs, while dependent variables are outputs or targets.
#
# </details>
#
# ---
#
# ### 40. Why is data visualization important in Data Science?
#
# <details>
# <summary>Show Answer</summary>
#
# It helps identify patterns, trends, and insights in data.
#
# </details>
#
# ---

# %% [markdown]
# ---
# # SECTION C: Advance questions
# ---

# %% [markdown]
# ### 41. A company wants to predict equipment failure based on sensor data. Would this problem use classification or regression?
#
# <details>
# <summary>Show Answer</summary>
#
# Classification, because the output predicts categories such as "Failure" or "No Failure."
#
# </details>
#
# ---
#
# ### 42. An AI model performs well during training but poorly during testing. What is the most likely issue?
#
# <details>
# <summary>Show Answer</summary>
#
# Overfitting.
#
# </details>
#
# ---
#
# ### 43. Why is preprocessing one of the most important stages in Machine Learning?
#
# <details>
# <summary>Show Answer</summary>
#
# Because clean and properly prepared data improves model accuracy and reliability.
#
# </details>
#
# ---
#
# ### 44. Explain one ethical concern in Artificial Intelligence.
#
# <details>
# <summary>Show Answer</summary>
#
# Bias in AI systems can lead to unfair decisions.
#
# </details>
#
# ---
#
# ### 45. A dataset contains thousands of empty values. How would this affect AI model performance?
#
# <details>
# <summary>Show Answer</summary>
#
# It can reduce accuracy, create bias, and make learning difficult.
#
# </details>
#
# ---
#
# ### 46. Why is model evaluation important before deployment?
#
# <details>
# <summary>Show Answer</summary>
#
# To ensure the model performs well on unseen real-world data.
#
# </details>
#
# ---
#
# ### 47. An organization wants to group customers based on purchasing behavior without labels. Which Machine Learning approach is suitable?
#
# <details>
# <summary>Show Answer</summary>
#
# Unsupervised learning (clustering).
#
# </details>
#
# ---
#
# ### 48. Why is Python considered beginner-friendly for AI development?
#
# <details>
# <summary>Show Answer</summary>
#
# Because of its simple syntax, readability, and large ecosystem of AI libraries.
#
# </details>
#
# ---
#
# ### 49. Describe one challenge beginners face in Machine Learning and how it can be overcome.
#
# <details>
# <summary>Show Answer</summary>
#
# One challenge is understanding mathematical concepts. It can be overcome through consistent practice and practical projects.
#
# </details>
#
# ---
#
# ### 50. If you were asked to build an AI solution for the Oil & Gas industry, what problem would you solve and why?
#
# <details>
# <summary>Show Answer</summary>
#
# Possible answers include predictive maintenance, PPE detection, gas leak detection, or incident analysis because these improve safety and operational efficiency.
#
# </details>
#
# ---

# %% [markdown]
# ## Reflection questions
#
# 1. Which topic was easiest for you?
# 2. Which topic do you still struggle with?
# 3. What AI field interests you most?
# 4. What project would you like to build?
# 5. What skills do you need to improve?
