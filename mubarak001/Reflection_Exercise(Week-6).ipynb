# %% [markdown]
# # Week 6 Reflection – AI/ML Journey
#
# This reflection will help you evaluate your progress, identify your strengths, and plan for improvement.
#
# Take your time and answer honestly.

# %% [markdown]
# ## Step 1: What Have I Learned?
#
# Think about everything we’ve covered so far.
#
# ### Topics:
# - Jupyter Notebook
# - Python Basics
# - Data Handling (Pandas)
# - Data Visualization (matplotlib)
# - Introduction to Machine Learning (scikit-learn)
# - Machine Learning models (Supervised Learning)
#
# ### Questions:
# - What topics have I learned so far?
# - What can I now do that I couldn’t do before?

# %%
#Run the cell first
learned = input("List what you have learned so far: ")
new_skills = input("What can you now do that you couldn’t do before? ")

print("\nYour Learning Summary:")
print(learned)
print(new_skills)
# Out:
# List what you have learned so far:  Data cleaning with Pandas, creating plots with Matplotlib, and the basics of Supervised Learning
# What can you now do that you couldn’t do before?  I can load a dataset, handle missing values, visualize trends using scatter plots, and build a basic linear regression model
# Your Learning Summary:
# Data cleaning with Pandas, creating plots with Matplotlib, and the basics of Supervised Learning
# I can load a dataset, handle missing values, visualize trends using scatter plots, and build a basic linear regression model

# %% [markdown]
# ## Step 2: What Can I Do Now?
#
# Complete this sentence:
#
# "Right now, I can..."
#
# List at least 5 skills.

# %%
#Run the cell to enter skills
skills = []

for i in range(5):
    skill = input(f"Enter skill {i+1}: ")
    skills.append(skill)

print("\nYour Skills:")
for s in skills:
    print("-", s)
# Out:
# Enter skill 1:  Filter and sort large datasets using Pandas
# Enter skill 2:  Create line, bar, and scatter plots to find data patterns.
# Enter skill 3:  Split data into training and testing sets using Scikit-Learn
# Enter skill 4:  Train a Linear Regression or Classification model
# Enter skill 5:  Evaluate model performance using accuracy scores or error metrics.
# Your Skills:
# - Filter and sort large datasets using Pandas
# - Create line, bar, and scatter plots to find data patterns.
# - Split data into training and testing sets using Scikit-Learn
# - Train a Linear Regression or Classification model
# - Evaluate model performance using accuracy scores or error metrics.

# %% [markdown]
# ## Step 3: My Strengths
#
# - Which tasks do I find easy?
# - Where do I feel confident?
# - Which assignment did I perform best in?

# %%
#Run the cell to enter strengths
strengths = input("What are your strongest areas? ")

print("\nYour Strengths:")
print(strengths)
# Out:
# What are your strongest areas?  I feel most confident in Data Visualization and Pandas because the visual feedback from plots makes it easy to see if my code is working
# Your Strengths:
# I feel most confident in Data Visualization and Pandas because the visual feedback from plots makes it easy to see if my code is working

# %% [markdown]
# ## Step 4: Areas for Improvement
#
# Be honest. This is how you grow.
#
# - Which topics confuse me?
# - Where do I struggle most?
# - What mistakes do I repeat?

# %%
#Run the cell to enter weakness
weakness = input("What are your weak areas? ")

print("\nAreas to Improve:")
print(weakness)
# Out:
# What are your weak areas?  I sometimes struggle with Matplotlib syntax (like formatting axes) and understanding the specific mathematical logic behind different ML algorithms.
# Areas to Improve:
# I sometimes struggle with Matplotlib syntax (like formatting axes) and understanding the specific mathematical logic behind different ML algorithms.

# %% [markdown]
# ## Step 5: Real-World Thinking
#
# - Can I solve any real-world problem?
# - If given a dataset, what can I do with it?
# - Can I explain AI/ML to someone else?

# %%
#Run the cell to enter real_world problem you can solve
real_world = input("Describe one problem you can solve with your current skills: ")

print("\nYour Real-World Application:")
print(real_world)
# Out:
# Describe one problem you can solve with your current skills:  I can use a housing dataset to build a model that predicts house prices based on features like square footage and location
# Your Real-World Application:
# I can use a housing dataset to build a model that predicts house prices based on features like square footage and location

# %% [markdown]
# ## Step 6: Effort & Consistency
#
# - Am I practicing regularly?
# - Do I try coding outside class?
# - Do I ask questions when I don’t understand?

# %%
#Run the cell to enter effort
effort = input("How consistent have you been in your learning? ")

print("\nYour Effort Reflection:")
print(effort)
# Out:
# How consistent have you been in your learning?  I haven't been as consistent as I hoped, I find myself rushing through the material once a week rather than practicing daily
# Your Effort Reflection:
# I haven't been as consistent as I hoped, I find myself rushing through the material once a week rather than practicing daily

# %% [markdown]
# ## Step 7: Improvement Plan (Next 4 Weeks)
#
# Complete this:
#
# "In the next 4 weeks, I will..."

# %%
#Run the cell to enter your improv. plan
plan = input("What will you improve in the next 4 weeks? ")

print("\nYour Plan:")
print(plan)
# Out:
# What will you improve in the next 4 weeks?  I will commit to 1 hour of coding every other day to build a more sustainable habit
# Your Plan:
# I will commit to 1 hour of coding every other day to build a more sustainable habit

# %% [markdown]
# ## Step 8: Motivation
#
# - Why did I join this program?
# - What do I want to become?

# %%
motivation = input("Why did you start this journey? ")

print("\nYour Motivation:")
print(motivation)
# Out:
# Why did you start this journey?  I am pursuing AI/Machine Learning to gain the technical expertise needed to build predictive models and transition into a career where I can solve complex data problems
# Your Motivation:
# I am pursuing AI/Machine Learning to gain the technical expertise needed to build predictive models and transition into a career where I can solve complex data problems

# %% [markdown]
# # Final Reflection
# You have completed your Week 6 reflection.
#
# **Remember**:
# - You started as a beginner. Now you can already build real things.
#
# NOTE: Stay consistent. Keep practicing. You are progressing.
