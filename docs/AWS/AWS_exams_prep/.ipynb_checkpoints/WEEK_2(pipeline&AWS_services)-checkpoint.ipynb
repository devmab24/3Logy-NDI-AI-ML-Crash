# %% [markdown]
# # AI/ML pipeline & AWS services

# %% [markdown]
# **Topics**:
#
# - Data Collection
# - EDA
# - Feature Engineering
# - Training
# - Evaluation
# - Deployment
# - Monitoring
#
# *The guide specifically requires understanding the AI/ML pipeline*
#
# ---
#
# **AWS services**:
#
# We'll learn:
#
# - Amazon S3
# - SageMaker AI
# - SageMaker JumpStart
# - Amazon Q
# - Amazon Bedrock
#
# These topics appear in the updated objectives.
#
# ---
#
# **Practice**:
#
# **We'll demontrate**:
#
#     S3
#
#      ↓
#
#     SageMaker Notebook
#
#      ↓
#
#     Training
#
#      ↓
#
#     Endpoint
#
# *We do not need to train complex models.*
